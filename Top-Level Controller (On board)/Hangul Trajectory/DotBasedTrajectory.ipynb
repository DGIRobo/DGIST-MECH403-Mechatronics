# %% [markdown]
# Hangul Trajectory Showing Function

# %%
import math
import matplotlib.pyplot as plt

def shower(word):
    x = []
    y = []
    z = []
    for dot in word:
        x.append(dot[0])
        y.append(dot[1])
        z.append(dot[2])
    ax = plt.figure(figsize=(5,5)).add_subplot(projection='3d')
    ax.axis([0, 1, 1, 0])
    ax.plot(x, y, z)
    ax.set_title("word trajectory 3d plot")

def stringShower(wordnum, string):
    x = []
    y = []
    z = []
    for dot in string:
        x.append(dot[0])
        y.append(dot[1])
        z.append(dot[2])
    ax = plt.figure().add_subplot(projection='3d')
    ax.axis([0, 0.7*wordnum, 0.7*wordnum, 0])
    ax.plot(x, y, z)
    ax.set_title("string trajectory 3d plot")

# %% [markdown]
# Word offset & resize, String maker

# %%
def offset(word, x, y):
    word = word.copy()
    for dot in range(0,len(word)):
        word[dot] = list(word[dot])
    for dot in range(0, len(word)):
        word[dot][0] = word[dot][0] + x
        word[dot][1] = word[dot][1] + y
    for dot in range(0,len(word)):
        word[dot] = tuple(word[dot])
    return word

def resize(word, xscale, yscale):
    word = word.copy()
    for dot in range(0,len(word)):
        word[dot] = list(word[dot])
    for dot in range(0, len(word)):
        word[dot][0] = word[dot][0] * xscale
        word[dot][1] = word[dot][1] * yscale
    for dot in range(0,len(word)):
        word[dot] = tuple(word[dot])
    return word

def string_dot(size, chars):
    string_dot_list = []
    i = 0
    for char in chars:
        char = offset(char, i*size, 0)
        string_dot_list = string_dot_list + char
        i = i + 0.7
    return string_dot_list

# %% [markdown]
# Type 1: 가
# Type 2: 각
# Type 3: 고
# Type 4: 곡
# Type 5: 과
# Type 6: 곽

# %%
def Type1(size, word1, word2):
    word1 = resize(word1, size*55/100, size*4/5)
    word2 = resize(word2, size*35/100, size*1)
    word1 = offset(word1, 0, size*1/10)
    word2 = offset(word2, size*65/100, 0)
    return resize(word1+word2, 0.6, 1)

def Type2(size, word1, word2, word3):
    temp = Type1(size, word1, word2)
    temp = resize(temp, size, size*55/100)
    word3 = resize(word3, size*0.6, size*35/100)
    word3 = offset(word3, 0, size*65/100)
    return resize(temp+word3, 1, 1)

def Type3(size, word1, word2):
    word1 = resize(word1, size*4/5, size*55/100)
    word2 = resize(word2, size*1, size*35/100)
    word1 = offset(word1, size*1/10, 0)
    word2 = offset(word2, 0, size*65/100)
    return resize(word1+word2, 0.6, 1)

def Type4(size, word1, word2, word3):
    temp = Type3(size, word1, word2)
    temp = resize(temp, size, size*65/100)
    word3 = resize(word3, size*4/5*0.6, size*25/100)
    word3 = offset(word3, size*1/10, size*75/100)
    return resize(temp+word3, 1, 1)

def Type5(size, word1, word2):
    pass

def Type6(size, word1, word2):
    pass

# %% [markdown]
# self._CHOSUNG_LIST = ['ㄱ', 'ㄲ', 'ㄴ', 'ㄷ', 'ㄸ', 'ㄹ', 'ㅁ', 'ㅂ', 'ㅃ', 'ㅅ', 'ㅆ', 'ㅇ', 'ㅈ', 'ㅉ', 'ㅊ', 'ㅋ', 'ㅌ', 'ㅍ', 'ㅎ']

# %%
CHOSUNGpivotX = 1 #단위: mm
CHOSUNGpivotY = 1 #단위: mm

# %%
# ㄱ
g = [(0, 0, False), 
     (0, 0, True), 
     (CHOSUNGpivotX, 0, True),
     (CHOSUNGpivotX, CHOSUNGpivotY, True),
     (CHOSUNGpivotX, CHOSUNGpivotY, False)]

#shower(g)

# %%
# ㄲ
kk = [(0, 0, False), 
     (0, 0, True), 
     (CHOSUNGpivotX*10/21, 0, True),
     (CHOSUNGpivotX*10/21, CHOSUNGpivotY, True),
     (CHOSUNGpivotX*10/21, CHOSUNGpivotY, False),
     (CHOSUNGpivotX*11/21, 0, False),
     (CHOSUNGpivotX*11/21, 0, True),
     (CHOSUNGpivotX, 0, True),
     (CHOSUNGpivotX, CHOSUNGpivotY, True),
     (CHOSUNGpivotX, CHOSUNGpivotY, False)]

#shower(kk)

# %%
# ㄴ
n = [(0, 0, False), 
     (0, 0, True), 
     (0, CHOSUNGpivotY, True),
     (CHOSUNGpivotX, CHOSUNGpivotY, True),
     (CHOSUNGpivotX, CHOSUNGpivotY, False)]

#shower(n)

# %%
# ㄷ
d = [(CHOSUNGpivotX, 0, False), 
     (CHOSUNGpivotX, 0, True), 
     (0, 0, True),
     (0, CHOSUNGpivotY, True),
     (CHOSUNGpivotX, CHOSUNGpivotY, True),
     (CHOSUNGpivotX, CHOSUNGpivotY, False)]

#shower(d)

# %%
# ㄸ
tt = [(CHOSUNGpivotX*10/21, 0, False), 
     (CHOSUNGpivotX*10/21, 0, True), 
     (0, 0, True),
     (0, CHOSUNGpivotY, True),
     (CHOSUNGpivotX*10/21, CHOSUNGpivotY, True),
     (CHOSUNGpivotX*10/21, CHOSUNGpivotY, False),
     (CHOSUNGpivotX, 0, False),
     (CHOSUNGpivotX, 0, True),
     (CHOSUNGpivotX*11/21, 0, True),
     (CHOSUNGpivotX*11/21, CHOSUNGpivotY, True),
     (CHOSUNGpivotX, CHOSUNGpivotY, True),
     (CHOSUNGpivotX, CHOSUNGpivotY, False)]

#shower(tt)

# %%
# ㄹ
r = [(0, 0, False), 
     (0, 0, True), 
     (CHOSUNGpivotX, 0, True),
     (CHOSUNGpivotX, CHOSUNGpivotY/2, True),
     (0, CHOSUNGpivotY/2, True),
     (0, CHOSUNGpivotY, True),
     (CHOSUNGpivotX, CHOSUNGpivotY, True),
     (CHOSUNGpivotX, CHOSUNGpivotY, False)]

#shower(r)

# %%
# ㅁ
m = [(0, 0, False), 
     (0, 0, True), 
     (CHOSUNGpivotX, 0, True),
     (CHOSUNGpivotX, CHOSUNGpivotY, True),
     (0, CHOSUNGpivotY, True),
     (0, 0, True),
     (0, 0, False)]

#shower(m)

# %%
# ㅂ
b = [(0, 0, False), 
     (0, 0, True), 
     (0, CHOSUNGpivotY, True),
     (CHOSUNGpivotX, CHOSUNGpivotY, True),
     (CHOSUNGpivotX, 0, True),
     (CHOSUNGpivotX, 0, False),
     (0, CHOSUNGpivotY/2, False),
     (0, CHOSUNGpivotY/2, True),
     (CHOSUNGpivotX, CHOSUNGpivotY/2, True),
     (CHOSUNGpivotX, CHOSUNGpivotY/2, False)]

#shower(b)

# %%
# ㅃ
pp = [(0, 0, False), 
     (0, 0, True), 
     (0, CHOSUNGpivotY, True),
     (CHOSUNGpivotX*10/21, CHOSUNGpivotY, True),
     (CHOSUNGpivotX*10/21, 0, True),
     (CHOSUNGpivotX*10/21, 0, False),
     (0, CHOSUNGpivotY/2, False),
     (0, CHOSUNGpivotY/2, True),
     (CHOSUNGpivotX*10/21, CHOSUNGpivotY/2, True),
     (CHOSUNGpivotX*10/21, CHOSUNGpivotY/2, False),
     (CHOSUNGpivotX*11/21, 0, False),
     (CHOSUNGpivotX*11/21, 0, True),
     (CHOSUNGpivotX*11/21, CHOSUNGpivotY, True),
     (CHOSUNGpivotX, CHOSUNGpivotY, True),
     (CHOSUNGpivotX, 0, True),
     (CHOSUNGpivotX, 0, False),
     (CHOSUNGpivotX*11/21, CHOSUNGpivotY/2, False),
     (CHOSUNGpivotX*11/21, CHOSUNGpivotY/2, True),
     (CHOSUNGpivotX, CHOSUNGpivotY/2, True),
     (CHOSUNGpivotX, CHOSUNGpivotY/2, False)]

#shower(pp)

# %%
# ㅅ
s = [(CHOSUNGpivotX/2, 0, False), 
     (CHOSUNGpivotX/2, 0, True), 
     (0, CHOSUNGpivotY, True),
     (0, CHOSUNGpivotY, False),
     (CHOSUNGpivotX/2, 0, False),
     (CHOSUNGpivotX/2, 0, True),
     (CHOSUNGpivotX, CHOSUNGpivotY, True),
     (CHOSUNGpivotX, CHOSUNGpivotY, False)]

#shower(s)

# %%
# ㅆ
ss = [(CHOSUNGpivotX*5/21, 0, False), 
     (CHOSUNGpivotX*5/21, 0, True), 
     (0, CHOSUNGpivotY, True),
     (0, CHOSUNGpivotY, False),
     (CHOSUNGpivotX*5/21, 0, False),
     (CHOSUNGpivotX*5/21, 0, True),
     (CHOSUNGpivotX*10/21, CHOSUNGpivotY, True),
     (CHOSUNGpivotX*10/21, CHOSUNGpivotY, False),
     (CHOSUNGpivotX*16/21, 0, False), 
     (CHOSUNGpivotX*16/21, 0, True), 
     (CHOSUNGpivotX*11/21, CHOSUNGpivotY, True),
     (CHOSUNGpivotX*11/21, CHOSUNGpivotY, False),
     (CHOSUNGpivotX*16/21, 0, False),
     (CHOSUNGpivotX*16/21, 0, True),
     (CHOSUNGpivotX, CHOSUNGpivotY, True),
     (CHOSUNGpivotX, CHOSUNGpivotY, False)]

#shower(ss)

# %%
# ㅇ
sampling = list(range(0, 361, 1))
ng = [(0, CHOSUNGpivotY/2, False)] + [((CHOSUNGpivotX/2) + (CHOSUNGpivotX/2)*math.cos(math.radians(180-dot)), CHOSUNGpivotY/2 + (CHOSUNGpivotY/2)*math.sin(math.radians(dot)), True) for dot in sampling] + [(0, CHOSUNGpivotY/2, False)]

#shower(ng)

# %%
# ㅈ
j = [(0, 0, False),
     (0, 0, True),
     (CHOSUNGpivotX, 0, True),
     (CHOSUNGpivotX, 0, False),
     (CHOSUNGpivotX/2, 0, False), 
     (CHOSUNGpivotX/2, 0, True), 
     (0, CHOSUNGpivotY, True),
     (0, CHOSUNGpivotY, False),
     (CHOSUNGpivotX/2, 0, False),
     (CHOSUNGpivotX/2, 0, True),
     (CHOSUNGpivotX, CHOSUNGpivotY, True),
     (CHOSUNGpivotX, CHOSUNGpivotY, False)]

#shower(j)

# %%
# ㅊ
ch = [(CHOSUNGpivotX*1/5, 0, False),
      (CHOSUNGpivotX*1/5, 0, True),
      (CHOSUNGpivotX*4/5, 0, True),
      (CHOSUNGpivotX*4/5, 0, False),
      (0, CHOSUNGpivotY*1/6, False),
      (0, CHOSUNGpivotY*1/6, True),
      (CHOSUNGpivotX, CHOSUNGpivotY*1/6, True),
      (CHOSUNGpivotX, CHOSUNGpivotY*1/6, False),
      (CHOSUNGpivotX/2, CHOSUNGpivotY*1/6, False), 
      (CHOSUNGpivotX/2, CHOSUNGpivotY*1/6, True), 
      (0, CHOSUNGpivotY, True),
      (0, CHOSUNGpivotY, False),
      (CHOSUNGpivotX/2, CHOSUNGpivotY*1/6, False),
      (CHOSUNGpivotX/2, CHOSUNGpivotY*1/6, True),
      (CHOSUNGpivotX, CHOSUNGpivotY, True),
      (CHOSUNGpivotX, CHOSUNGpivotY, False)]

#shower(ch)

# %%
# ㅋ
k = [(0, 0, False), 
     (0, 0, True), 
     (CHOSUNGpivotX, 0, True),
     (CHOSUNGpivotX, CHOSUNGpivotY, True),
     (CHOSUNGpivotX, CHOSUNGpivotY, False),
     (0, CHOSUNGpivotY/2, False),
     (0, CHOSUNGpivotY/2, True),
     (CHOSUNGpivotX, CHOSUNGpivotY/2, True),
     (CHOSUNGpivotX, CHOSUNGpivotY/2, False)]

#shower(k)

# %%
# ㅌ
t = [(CHOSUNGpivotX, 0, False), 
     (CHOSUNGpivotX, 0, True), 
     (0, 0, True),
     (0, CHOSUNGpivotY, True),
     (CHOSUNGpivotX, CHOSUNGpivotY, True),
     (CHOSUNGpivotX, CHOSUNGpivotY, False),
     (0, CHOSUNGpivotY/2, False),
     (0, CHOSUNGpivotY/2, True),
     (CHOSUNGpivotX, CHOSUNGpivotY/2, True),
     (CHOSUNGpivotX, CHOSUNGpivotY/2, False)]

#shower(t)

# %%
# ㅍ
p = [(0, 0, False), 
     (0, 0, True), 
     (0, 0, True),
     (CHOSUNGpivotX, 0, True),
     (CHOSUNGpivotX, 0, False),
     (0, CHOSUNGpivotY, False),
     (0, CHOSUNGpivotY, True),
     (CHOSUNGpivotX, CHOSUNGpivotY, True),
     (CHOSUNGpivotX, CHOSUNGpivotY, False),
     (CHOSUNGpivotX/3, 0, False),
     (CHOSUNGpivotX/3, 0, True),
     (CHOSUNGpivotX/3, CHOSUNGpivotY, True),
     (CHOSUNGpivotX/3, CHOSUNGpivotY, False),
     (CHOSUNGpivotX*2/3, 0, False),
     (CHOSUNGpivotX*2/3, 0, True),
     (CHOSUNGpivotX*2/3, CHOSUNGpivotY, True),
     (CHOSUNGpivotX*2/3, CHOSUNGpivotY, False)]

#shower(p)

# %%
# ㅎ
h = [(CHOSUNGpivotX*1/5, 0, False),
      (CHOSUNGpivotX*1/5, 0, True),
      (CHOSUNGpivotX*4/5, 0, True),
      (CHOSUNGpivotX*4/5, 0, False),
      (0, CHOSUNGpivotY*1/6, False),
      (0, CHOSUNGpivotY*1/6, True),
      (CHOSUNGpivotX, CHOSUNGpivotY*1/6, True),
      (CHOSUNGpivotX, CHOSUNGpivotY*1/6, False)] + offset(resize(ng, 9/12, 9/12), 0.5 - 9/24, 3/12)

#shower(h)

# %% [markdown]
# self._JUNGSUNG_LIST = ['ㅏ', 'ㅐ', 'ㅑ', 'ㅒ', 'ㅓ', 'ㅔ', 'ㅕ', 'ㅖ', 'ㅗ', 'ㅘ', 'ㅙ', 'ㅚ', 'ㅛ', 'ㅜ', 'ㅝ', 'ㅞ', 'ㅟ', 'ㅠ', 'ㅡ', 'ㅢ', 'ㅣ']

# %%
JUNGSUNGpivotX = 1 #단위: mm
JUNGSUNGpivotY = 1 #단위: mm

# %%
# ㅏ
a = [(0, 0, False), 
     (0, 0, True),
     (0, JUNGSUNGpivotY, True),
     (0, JUNGSUNGpivotY, False),
     (0, JUNGSUNGpivotY/2, False),
     (0, JUNGSUNGpivotY/2, True),
     (JUNGSUNGpivotX, JUNGSUNGpivotY/2, True),
     (JUNGSUNGpivotX, JUNGSUNGpivotY/2, False)]

#shower(a)

# %%
# ㅐ
ae = [(0, 0, False), 
     (0, 0, True), 
     (0, JUNGSUNGpivotY, True),
     (0, JUNGSUNGpivotY, False),
     (JUNGSUNGpivotX, 0, False),
     (JUNGSUNGpivotX, 0, True),
     (JUNGSUNGpivotX, JUNGSUNGpivotY, True),
     (JUNGSUNGpivotX, JUNGSUNGpivotY, False),
     (0, JUNGSUNGpivotY/2, False),
     (0, JUNGSUNGpivotY/2, True),
     (JUNGSUNGpivotX, JUNGSUNGpivotY/2, True),
     (JUNGSUNGpivotX, JUNGSUNGpivotY/2, False)]

#shower(ae)

# %%
# ㅑ
ya = [(0, 0, False), 
     (0, 0, True), 
     (0, JUNGSUNGpivotY, True),
     (0, JUNGSUNGpivotY, False),
     (0, JUNGSUNGpivotY/3, False),
     (0, JUNGSUNGpivotY/3, True),
     (JUNGSUNGpivotX, JUNGSUNGpivotY/3, True),
     (JUNGSUNGpivotX, JUNGSUNGpivotY/3, False),
     (0, JUNGSUNGpivotY*2/3, False),
     (0, JUNGSUNGpivotY*2/3, True),
     (JUNGSUNGpivotX, JUNGSUNGpivotY*2/3, True),
     (JUNGSUNGpivotX, JUNGSUNGpivotY*2/3, False)]

#shower(ya)

# %%
# ㅒ
yae = [(0, 0, False), 
     (0, 0, True), 
     (0, JUNGSUNGpivotY, True),
     (0, JUNGSUNGpivotY, False),
     (JUNGSUNGpivotX, 0, False),
     (JUNGSUNGpivotX, 0, True),
     (JUNGSUNGpivotX, JUNGSUNGpivotY, True),
     (JUNGSUNGpivotX, JUNGSUNGpivotY, False),
     (0, JUNGSUNGpivotY/3, False),
     (0, JUNGSUNGpivotY/3, True),
     (JUNGSUNGpivotX, JUNGSUNGpivotY/3, True),
     (JUNGSUNGpivotX, JUNGSUNGpivotY/3, False),
     (0, JUNGSUNGpivotY*2/3, False),
     (0, JUNGSUNGpivotY*2/3, True),
     (JUNGSUNGpivotX, JUNGSUNGpivotY*2/3, True),
     (JUNGSUNGpivotX, JUNGSUNGpivotY*2/3, False)]

#shower(yae)

# %%
# ㅓ
eo = [(0, JUNGSUNGpivotY/2, False),
     (0, JUNGSUNGpivotY/2, True),
     (JUNGSUNGpivotX, JUNGSUNGpivotY/2, True),
     (JUNGSUNGpivotX, JUNGSUNGpivotY/2, False),
     (JUNGSUNGpivotX, 0, False), 
     (JUNGSUNGpivotX, 0, True), 
     (JUNGSUNGpivotX, JUNGSUNGpivotY, True),
     (JUNGSUNGpivotX, JUNGSUNGpivotY, False)]

#shower(eo)

# %%
# ㅔ
e = [(0, JUNGSUNGpivotY/2, False),
     (0, JUNGSUNGpivotY/2, True),
     (JUNGSUNGpivotX/2, JUNGSUNGpivotY/2, True),
     (JUNGSUNGpivotX/2, JUNGSUNGpivotY/2, False),
     (JUNGSUNGpivotX/2, 0, False), 
     (JUNGSUNGpivotX/2, 0, True), 
     (JUNGSUNGpivotX/2, JUNGSUNGpivotY, True),
     (JUNGSUNGpivotX/2, JUNGSUNGpivotY, False),
     (JUNGSUNGpivotX, 0, False), 
     (JUNGSUNGpivotX, 0, True), 
     (JUNGSUNGpivotX, JUNGSUNGpivotY, True),
     (JUNGSUNGpivotX, JUNGSUNGpivotY, False)]

#shower(e)

# %%
# ㅕ
yeo = [(0, JUNGSUNGpivotY/3, False),
       (0, JUNGSUNGpivotY/3, True),
       (JUNGSUNGpivotX, JUNGSUNGpivotY/3, True),
       (JUNGSUNGpivotX, JUNGSUNGpivotY/3, False),
       (0, JUNGSUNGpivotY*2/3, False),
       (0, JUNGSUNGpivotY*2/3, True),
       (JUNGSUNGpivotX, JUNGSUNGpivotY*2/3, True),
       (JUNGSUNGpivotX, JUNGSUNGpivotY*2/3, False),
       (JUNGSUNGpivotX, 0, False), 
       (JUNGSUNGpivotX, 0, True), 
       (JUNGSUNGpivotX, JUNGSUNGpivotY, True),
       (JUNGSUNGpivotX, JUNGSUNGpivotY, False),]

#shower(yeo)

# %%
# ㅖ
ye = [(0, JUNGSUNGpivotY/3, False),
       (0, JUNGSUNGpivotY/3, True),
       (JUNGSUNGpivotX/2, JUNGSUNGpivotY/3, True),
       (JUNGSUNGpivotX/2, JUNGSUNGpivotY/3, False),
       (0, JUNGSUNGpivotY*2/3, False),
       (0, JUNGSUNGpivotY*2/3, True),
       (JUNGSUNGpivotX/2, JUNGSUNGpivotY*2/3, True),
       (JUNGSUNGpivotX/2, JUNGSUNGpivotY*2/3, False),
       (JUNGSUNGpivotX/2, 0, False), 
       (JUNGSUNGpivotX/2, 0, True), 
       (JUNGSUNGpivotX/2, JUNGSUNGpivotY, True),
       (JUNGSUNGpivotX/2, JUNGSUNGpivotY, False),
       (JUNGSUNGpivotX, 0, False), 
       (JUNGSUNGpivotX, 0, True), 
       (JUNGSUNGpivotX, JUNGSUNGpivotY, True),
       (JUNGSUNGpivotX, JUNGSUNGpivotY, False),]

#shower(ye)

# %%
# ㅗ
o = [(JUNGSUNGpivotX/2, 0, False), 
     (JUNGSUNGpivotX/2, 0, True),
     (JUNGSUNGpivotX/2, JUNGSUNGpivotY, True),
     (JUNGSUNGpivotX/2, JUNGSUNGpivotY, False),
     (0, JUNGSUNGpivotY, False),
     (0, JUNGSUNGpivotY, True),
     (JUNGSUNGpivotX, JUNGSUNGpivotY, True),
     (JUNGSUNGpivotX, JUNGSUNGpivotY, False)]

#shower(o)

# %%
# ㅘ
wa = offset(resize(o, 4/5, 1/5), 0, 3/5) + offset(resize(a, 1/5, 1), 4/5, 0)

#shower(wa)

# %%
# ㅙ
wae = offset(resize(o, 4/5, 1/5), 0, 3/5) + offset(resize(ae, 1/5, 1), 4/5, 0)

#shower(wae)

# %%
# ㅚ
oe = offset(resize(o, 9/10, 1/5), 0, 3/5) + offset(resize(i, 1/5, 1), 4/5, 0)

#shower(oe)

# %%
# ㅛ
yo = [(JUNGSUNGpivotX/3, 0, False), 
     (JUNGSUNGpivotX/3, 0, True),
     (JUNGSUNGpivotX/3, JUNGSUNGpivotY, True),
     (JUNGSUNGpivotX/3, JUNGSUNGpivotY, False),
     (JUNGSUNGpivotX*2/3, 0, False), 
     (JUNGSUNGpivotX*2/3, 0, True),
     (JUNGSUNGpivotX*2/3, JUNGSUNGpivotY, True),
     (JUNGSUNGpivotX*2/3, JUNGSUNGpivotY, False),
     (0, JUNGSUNGpivotY, False),
     (0, JUNGSUNGpivotY, True),
     (JUNGSUNGpivotX, JUNGSUNGpivotY, True),
     (JUNGSUNGpivotX, JUNGSUNGpivotY, False)]

#shower(yo)

# %%
# ㅜ
u = [(0, 0, False),
     (0, 0, True),
     (JUNGSUNGpivotX, 0, True),
     (JUNGSUNGpivotX, 0, False),
     (JUNGSUNGpivotX/2, 0, False), 
     (JUNGSUNGpivotX/2, 0, True),
     (JUNGSUNGpivotX/2, JUNGSUNGpivotY, True),
     (JUNGSUNGpivotX/2, JUNGSUNGpivotY, False),]

#shower(u)

# %%
# ㅝ
wo = offset(resize(u, 4/5, 1/5), 0, 4/5) + offset(resize(offset(resize(offset(eo, 0, -1/4), 1/5, 2), 0, 1/2), 1, 1/2), 4/5, 0)

shower(wo)

# %%
# ㅞ
we = offset(resize(u, 4/5, 1/5), 0, 4/5) + offset(resize(e, 1/5, 1), 4/5, 0)

shower(we)

# %%
# ㅟ
wi = offset(resize(u, 9/10, 1/5), 0, 4/5) + offset(resize(i, 1/5, 1), 4/5, 0)

#shower(wi)

# %%
# ㅠ
yu = [(0, 0, False),
     (0, 0, True),
     (JUNGSUNGpivotX, 0, True),
     (JUNGSUNGpivotX, 0, False),
     (JUNGSUNGpivotX/3, 0, False), 
     (JUNGSUNGpivotX/3, 0, True),
     (JUNGSUNGpivotX/3, JUNGSUNGpivotY, True),
     (JUNGSUNGpivotX/3, JUNGSUNGpivotY, False),
     (JUNGSUNGpivotX*2/3, 0, False), 
     (JUNGSUNGpivotX*2/3, 0, True),
     (JUNGSUNGpivotX*2/3, JUNGSUNGpivotY, True),
     (JUNGSUNGpivotX*2/3, JUNGSUNGpivotY, False),]

#shower(yu)

# %%
# ㅡ
eu = [(0, JUNGSUNGpivotY/2, False),
     (0, JUNGSUNGpivotY/2, True),
     (JUNGSUNGpivotX, JUNGSUNGpivotY/2, True),
     (JUNGSUNGpivotX, JUNGSUNGpivotY/2, False)]

#shower(eu)

# %%
# ㅢ
ui = offset(resize(eu, 9/10, 1/5), 0, 7/10) + offset(resize(i, 1/5, 1), 4/5, 0)

#shower(ui)

# %%
# ㅣ
i = [(JUNGSUNGpivotX/2, 0, False),
     (JUNGSUNGpivotX/2, 0, True),
     (JUNGSUNGpivotX/2, JUNGSUNGpivotY, True),
     (JUNGSUNGpivotX/2, JUNGSUNGpivotY, False)]

#shower(i)

# %% [markdown]
# self._JONGSUNG_LIST = [' ', 'ㄱ', 'ㄲ', 'ㄳ', 'ㄴ', 'ㄵ', 'ㄶ', 'ㄷ', 'ㄹ', 'ㄺ', 'ㄻ', 'ㄼ', 'ㄽ', 'ㄾ', 'ㄿ', 'ㅀ', 'ㅁ', 'ㅂ', 'ㅄ', 'ㅅ', 'ㅆ', 'ㅇ', 'ㅈ', 'ㅊ', 'ㅋ', 'ㅌ', 'ㅍ', 'ㅎ']

# %%
# ㄳ
gs = resize(g + offset(s, 1.1, 0), 10/21, 1)

#shower(gs)

# %%
# ㄵ
nj = resize(n + offset(j, 1.1, 0), 10/21, 1)

#shower(nj)

# %%
# ㄶ
#nh

# %%
# ㄺ
rg = resize(r + offset(g, 1.1, 0), 10/21, 1)

#shower(rg)

# %%
# ㄻ
#rm
rm = resize(r + offset(m, 1.1, 0), 10/21, 1)

#shower(rm)

# %%
# ㄼ
rb = resize(r + offset(b, 1.1, 0), 10/21, 1)

#shower(rb)

# %%
# ㄽ
rs = resize(r + offset(s, 1.1, 0), 10/21, 1)

#shower(rs)

# %%
# ㄾ
rt = resize(r + offset(t, 1.1, 0), 10/21, 1)

#shower(rt)

# %%
# ㄿ
rp = resize(r + offset(p, 1.1, 0), 10/21, 1)

#shower(rp)

# %%
# ㅀ
#rh

# %%
# ㅄ
bs = resize(b + offset(s, 1.1, 0), 10/21, 1)

#shower(bs)

# %% [markdown]
# Type 1: 가 Type 2: 각 Type 3: 고 Type 4: 곡 Type 5: 과 Type 6: 곽

# %%
# Combine
stringShower(3, string_dot(1, [Type2(1, k, eo, m), Type3(1, p, yu), Type1(1, t, eo)]))
stringShower(2, string_dot(1, [Type2(1, j, eo, r), Type1(1, d, ae)]))
stringShower(2, string_dot(1, [Type1(1, ng, a), Type1(1, h, a)]))

# %%
stringShower(4, string_dot(1, [Type1(1, d, i), Type1(1, j, i), Type3(1, s, eu), Type3(1, t, eu)]))
stringShower(4, string_dot(1, [Type3(1, s, u), Type4(1, n, eu, ng), Type4(1, t, eu, g), Type2(1, g, a, ng)]))
